# %% [markdown]
# # Final Exam
#
# # Background on Python, iPython, Jupyter and Pandas
#
# [Python](https://www.python.org/) is a high-level general purpose programming language named after a [British comedy troup](https://www.youtube.com/user/MontyPython), created by a [Dutch programmer as a hobby project](http://en.wikipedia.org/wiki/Guido_van_Rossum) and maintained by an international group of friendly but opinionated python enthusiasts (`import this!`). Until June 2018, Guido van Rossum was the [Benevolent dictator for life](https://en.wikipedia.org/wiki/Benevolent_dictator_for_life) for the Python language, now decisions are made jointly by the Python Steering Council.
#
# Python is popular for data science because it's powerful, fast, plays well with others, runs everywhere, is easy to learn, highly readable, and open. Because it's general purpose it can be used for full-stack development. It's got a growing list of useful libraries for scientitic programming, data manipulation, data analysis. (Numpy, Scipy, Pandas, Scikit-Learn, Statsmodels, Matplotlib, Pybrain, etc.)
#
# [iPython](http://ipython.org/) is an enhanced, interactive python interpreter started as a grad school project by [Fernando Perez](http://fperez.org/). iPython (jupyter) notebooks allow you to run a multi-language (Python, R, Julia, Markdown, LaTex, etc) interpreter in your browser to create rich, portable, and sharable code documents.
#
# [Pandas](http://pandas.pydata.org/) is a libary created by [Wes McKinney](http://blog.wesmckinney.com/) that introduces the R-like dataframe object to Python and makes working with data in Python a lot easier. It's also a lot more efficient than the R dataframe and pretty much makes Python superior to R in every imaginable way (except for ggplot 2).
#
#
# # Final Exam
#
# This self-grading notebook serves as a final exam for the introductory course.
# If you have grasped the contents of the course, you should be able to complete
# this exam.
#
# It is essential that you answer each cell by assigning the solution to `QUESTION_#`
# where `#` is the question number.
#
# We will start with a warm-up question that is already answered.
#
# ## Getting started with Jupyter (iPython) Notebooks
#
# To start up a Jupyter notebook server, simply navigate to the directory where you want the notebooks to be saved and run the command
#
# ```
# jupyter notebook
# ```
#
# A browser should open with a notebook navigator. Click the "New" button and select "Python 3".
#
# A beautiful blank notebook should open in a new tab
#
# Name the notebook by clicking on "Untitled" at the top of the page.
#
# Notebooks are squences of cells. Cells can be markdown, code, or raw text. Change the first cell to markdown and briefly describe what you are going to do in the notebook.
#
# ## Getting started with Pandas
#
# We start by importing the libraries we're going to use any library in the notebook:E.G., `pandas` and `matplotlib`, `seaborn`, `Numpy`, `Statsmodels`
#
#
#
# ## Question 0
#
# Create a 3-element 1-dimensional array containing the values [1,1,1]
#
# _Note_: This answer is not assessed.

# %%
# Import Statements
import pandas as pd
import numpy as np
# %matplotlib inline

# Setup: The solution is used as a model

QUESTION_0 = np.ones(3)

# %%
QUESTION_0 = np.ones(3)
QUESTION_0
# Out:
# array([1., 1., 1.])

# %% [markdown]
# ## Accessing Documentation with ``?``
#
# The Python language and its data science ecosystem is built with the user in mind, and one big part of that is access to documentation.
# Every Python object contains the reference to a string, known as a *doc string*, which in most cases will contain a concise summary of the object and how to use it.
# Python has a built-in ``help()`` function that can access this information and prints the results.
# For example, to see the documentation of the built-in ``len`` function, you can do the following:
#
# ```ipython
# In [1]: help(len)
# Help on built-in function len in module builtins:
#
# len(...)
#     len(object) -> integer
#
#     Return the number of items of a sequence or mapping.
# ```
#
# Depending on your interpreter, this information may be displayed as inline text, or in some separate pop-up window.

# %% [markdown]
# ## Loading data into a Pandas DataFrame
#
# So far we've been working with many datasets and raw files during our class sessions. This functions below should be familiar for your to apply through out the exam
#
# Built-in Data Structures
# - strings ""
# - lists []
# - tuples ()
# - sets {}
# - dictionaries {'key':value}
#
# Additional Essential Data Structures
#
# - numpy arrays ([])
# - pandas Series
# - pandas DataFrame
# - tensorflow Tensors
#
#
# Today we'll primarily be working with the pandas DataFrame. The pandas DataFrame is a two-dimensional size-mutable, potentially heterogeneous tabular data structure with labeled axes. It's basically a spreadsheet you can program and it's an incredibly useful Python object for data analysis.
#
# You can load data into a dataframe using Pandas' excellent `read_*` functions.
#
# We're going to try two of them: read_table & read_csv
#
# Pro tip: TAB COMPLETION!
#
# Pro tip: jupyter will pull the doc string for a command just by asking it a question.
#
# Pro tip: jupyter will give you the allowable arguments if you hit `shift + tab`

# %% [markdown]
# ## Question 1 (a) (i)
#
# Construct the correlation matrix
#
# $$\left[\begin{array}{ccc} 1 & 0.2 & 0.5 \\ 0.2 & 1 & 0.8 \\ 0.5 & 0.8 & 1 \end{array}\right]$$
#
# as a NumPy array.

# %%
#1(i)
n = np.array([[1, 0.2, 0.5], [0.2, 1, 0.8], [0.5, 0.8, 1]])   #creating a numpy array 
n    #printing the array
# Out:
# array([[1. , 0.2, 0.5],
#        [0.2, 1. , 0.8],
#        [0.5, 0.8, 1. ]])

# %% [markdown]
# ## (ii)
#  Construct the correlation matrix
#
# $$\left[\begin{array}{ccc} 1 & 0.2 & 0.5 \\ 0.2 & 1 & 0.8 \\ 0.5 & 0.8 & 1 \end{array}\right]$$
#
# as a DataFrame with columns and index both equal to `['A', 'B', 'C']`.

# %%
array_1 =np.array([[1, 0.2, 0.5], [0.2, 1, 0.8], [0.5, 0.8, 1]])     #creating a numpy array
df = pd.DataFrame(array_1, index=["A", "B", "C"], columns=["A", "B", "C"])  #cearting a dataframe from the array formed

# %%
df #printing the dataframe
# Out:
#      A    B    C
# A  1.0  0.2  0.5
# B  0.2  1.0  0.8
# C  0.5  0.8  1.0

# %% [markdown]
# ## Question 1 (iii)
#
# Load the momentum data in the CSV file `momentum.csv`, set the column `date`
# as the index, and ensure that `date` is a `DateTimeIndex`.

# %%
data = pd.read_csv('momentum.csv')   #loading the momentum.csv file

pd.to_datetime(data.date) #sets the date as a DateTimeIndex


data #prints the dataframe
# Out:
#            date  mom_01  mom_02  mom_03  mom_04  mom_05  mom_06  mom_07  \
# 0    2016-01-04    0.67   -0.03   -0.93   -1.11   -1.47   -1.66   -1.40
# 1    2016-01-05   -0.36    0.20   -0.37    0.28    0.16    0.18   -0.22
# 2    2016-01-06   -4.97   -2.33   -2.60   -1.16   -1.70   -1.45   -1.15
# 3    2016-01-07   -4.91   -1.91   -3.03   -1.87   -2.31   -2.30   -2.70
# 4    2016-01-08   -0.40   -1.26   -0.98   -1.26   -1.13   -1.02   -0.96
# ..          ...     ...     ...     ...     ...     ...     ...     ...
# 498  2017-12-22    0.24    0.13   -0.07   -0.01   -0.08   -0.10   -0.14
# 499  2017-12-26    0.89    0.70    0.23   -0.03    0.10   -0.06   -0.14
# 500  2017-12-27   -0.58   -0.55   -0.27   -0.19   -0.14    0.18    0.18
# 501  2017-12-28    0.14    0.23    0.32    0.02    0.29    0.16    0.30
# 502  2017-12-29   -0.42   -0.61   -0.48   -0.57   -0.45   -0.41   -0.52
#
#      mom_08  mom_09  mom_10
# 0     -2.08   -1.71   -2.67
# 1      0.25    0.29    0.13
# 2     -1.46   -1.14   -0.45
# 3     -2.31   -2.36   -2.66
# 4     -1.42   -0.94   -1.32
# ..      ...     ...     ...
# 498   -0.16   -0.05   -0.01
# 499   -0.07    0.14   -0.65
# 500    0.10    0.22    0.36
# 501    0.15    0.28    0.29
# 502   -0.45   -0.70   -0.94
#
# [503 rows x 11 columns]

# %%
data.set_index('date')  #set date column as the index

# %% [markdown]
# ## Question 1 (iv) ##
#
# (a). Construct a DataFrame using the data loaded in the previous question 1 (iii)
# that contains the returns from momentum portfolio 5 in March and April 2016.
#
# (b). Load another data in the csv file `crimes.csv`and modify it into a dataframe using:
#
# HINT:Notice that that has some issues when it comes to column names. Your are required to fix the issues by editing, monipulating and probably deleting some clumns columns.:
#
# The expected solutions and cleaned data should implement:
#
# 1. Remove white spaces
#
# 2. Replacing spaces with underscore
#
# 3. You should also remove the double occurence of "_" in DATE__OF_OCCURENCE. Do so below:
#
# 4. Write code to drop column 'Location':
#
# 5. Once cleaned, we would like you to describe the better global view of the dataset. By writing code to describe, generate a sum (of null).
#
# 6. Select and subsett in pandas using: `''` or quote methods or .head methods on PRIMARY_DESCRIPTION column
#
# 7. Obtain the value counts for PRIMARY_DESCRIPTION column
#
# 8. selecting two columns: enter code to select two columns. It will look something like: dataframe[[column 1, column 2]] for
# 'PRIMARY_DESCRIPTION', 'SECONDARY_DESCRIPTION']] and view only the few columns (first ten),then subset by row index also for the first ten (3:10)
#
# 9. Data Sorting: Write code to sort values for theft column according to the date of occurance, in ascending and make use of inplace function argument. `HINT: You may realise that the something is not right especially the way the sort function is sorting the data. If your are convinced by this statement. Ensure that the date objects are handled well`.
#
# 10. Finally apply `Functions to series` use `Group by` year and month to look at data on a month to month basis.

# %%
#1(iv)(a)(iii)
data.date.unique()    #display the values in the date column
# Out:
# array(['2016-01-04', '2016-01-05', '2016-01-06', '2016-01-07',
#        '2016-01-08', '2016-01-11', '2016-01-12', '2016-01-13',
#        '2016-01-14', '2016-01-15', '2016-01-19', '2016-01-20',
#        '2016-01-21', '2016-01-22', '2016-01-25', '2016-01-26',
#        '2016-01-27', '2016-01-28', '2016-01-29', '2016-02-01',
#        '2016-02-02', '2016-02-03', '2016-02-04', '2016-02-05',
#        '2016-02-08', '2016-02-09', '2016-02-10', '2016-02-11',
#        '2016-02-12', '2016-02-16', '2016-02-17', '2016-02-18',
#        '2016-02-19', '2016-02-22', '2016-02-23', '2016-02-24',
#        '2016-02-25', '2016-02-26', '2016-02-29', '2016-03-01',
#        '2016-03-02', '2016-03-03', '2016-03-04', '2016-03-07',
#        '2016-03-08', '2016-03-09', '2016-03-10', '2016-03-11',
#        '2016-03-14', '2016-03-15', '2016-03-16', '2016-03-17',
#        '2016-03-18', '2016-03-21', '2016-03-22', '2016-03-23',
#        '2016-03-24', '2016-03-28', '2016-03-29', '2016-03-30',
#        '2016-03-31', '2016-04-01', '2016-04-04', '2016-04-05',
#        '2016-04-06', '2016-04-07', '2016-04-08', '2016-04-11',
#        '2016-04-12', '2016-04-13', '2016-04-14', '2016-04-15',
#        '2016-04-18', '2016-04-19', '2016-04-20', '2016-04-21',
#        '2016-04-22', '2016-04-25', '2016-04-26', '2016-04-27',
#        '2016-04-28', '2016-04-29', '2016-05-02', '2016-05-03',
#        '2016-05-04', '2016-05-05', '2016-05-06', '2016-05-09',
#        '2016-05-10', '2016-05-11', '2016-05-12', '2016-05-13',
#        '2016-05-16', '2016-05-17', '2016-05-18', '2016-05-19',
#        '2016-05-20', '2016-05-23', '2016-05-24', '2016-05-25',
#        '2016-05-26', '2016-05-27', '2016-05-31', '2016-06-01',
#        '2016-06-02', '2016-06-03', '2016-06-06', '2016-06-07',
#        '2016-06-08', '2016-06-09', '2016-06-10', '2016-06-13',
#        '2016-06-14', '2016-06-15', '2016-06-16', '2016-06-17',
#        '2016-06-20', '2016-06-21', '2016-06-22', '2016-06-23',
#        '2016-06-24', '2016-06-27', '2016-06-28', '2016-06-29',
#        '2016-06-30', '2016-07-01', '2016-07-05', '2016-07-06',
#        '2016-07-07', '2016-07-08', '2016-07-11', '2016-07-12',
#        '2016-07-13', '2016-07-14', '2016-07-15', '2016-07-18',
#        '2016-07-19', '2016-07-20', '2016-07-21', '2016-07-22',
#        '2016-07-25', '2016-07-26', '2016-07-27', '2016-07-28',
#        '2016-07-29', '2016-08-01', '2016-08-02', '2016-08-03',
#        '2016-08-04', '2016-08-05', '2016-08-08', '2016-08-09',
#        '2016-08-10', '2016-08-11', '2016-08-12', '2016-08-15',
#        '2016-08-16', '2016-08-17', '2016-08-18', '2016-08-19',
#        '2016-08-22', '2016-08-23', '2016-08-24', '2016-08-25',
#        '2016-08-26', '2016-08-29', '2016-08-30', '2016-08-31',
#        '2016-09-01', '2016-09-02', '2016-09-06', '2016-09-07',
#        '2016-09-08', '2016-09-09', '2016-09-12', '2016-09-13',
#        '2016-09-14', '2016-09-15', '2016-09-16', '2016-09-19',
#        '2016-09-20', '2016-09-21', '2016-09-22', '2016-09-23',
#        '2016-09-26', '2016-09-27', '2016-09-28', '2016-09-29',
#        '2016-09-30', '2016-10-03', '2016-10-04', '2016-10-05',
#        '2016-10-06', '2016-10-07', '2016-10-10', '2016-10-11',
#        '2016-10-12', '2016-10-13', '2016-10-14', '2016-10-17',
#        '2016-10-18', '2016-10-19', '2016-10-20', '2016-10-21',
#        '2016-10-24', '2016-10-25', '2016-10-26', '2016-10-27',
#        '2016-10-28', '2016-10-31', '2016-11-01', '2016-11-02',
#        '2016-11-03', '2016-11-04', '2016-11-07', '2016-11-08',
#        '2016-11-09', '2016-11-10', '2016-11-11', '2016-11-14',
#        '2016-11-15', '2016-11-16', '2016-11-17', '2016-11-18',
#        '2016-11-21', '2016-11-22', '2016-11-23', '2016-11-25',
#        '2016-11-28', '2016-11-29', '2016-11-30', '2016-12-01',
#        '2016-12-02', '2016-12-05', '2016-12-06', '2016-12-07',
#        '2016-12-08', '2016-12-09', '2016-12-12', '2016-12-13',
#        '2016-12-14', '2016-12-15', '2016-12-16', '2016-12-19',
#        '2016-12-20', '2016-12-21', '2016-12-22', '2016-12-23',
#        '2016-12-27', '2016-12-28', '2016-12-29', '2016-12-30',
#        '2017-01-03', '2017-01-04', '2017-01-05', '2017-01-06',
#        '2017-01-09', '2017-01-10', '2017-01-11', '2017-01-12',
#        '2017-01-13', '2017-01-17', '2017-01-18', '2017-01-19',
#        '2017-01-20', '2017-01-23', '2017-01-24', '2017-01-25',
#        '2017-01-26', '2017-01-27', '2017-01-30', '2017-01-31',
#        '2017-02-01', '2017-02-02', '2017-02-03', '2017-02-06',
#        '2017-02-07', '2017-02-08', '2017-02-09', '2017-02-10',
#        '2017-02-13', '2017-02-14', '2017-02-15', '2017-02-16',
#        '2017-02-17', '2017-02-21', '2017-02-22', '2017-02-23',
#        '2017-02-24', '2017-02-27', '2017-02-28', '2017-03-01',
#        '2017-03-02', '2017-03-03', '2017-03-06', '2017-03-07',
#        '2017-03-08', '2017-03-09', '2017-03-10', '2017-03-13',
#        '2017-03-14', '2017-03-15', '2017-03-16', '2017-03-17',
#        '2017-03-20', '2017-03-21', '2017-03-22', '2017-03-23',
#        '2017-03-24', '2017-03-27', '2017-03-28', '2017-03-29',
#        '2017-03-30', '2017-03-31', '2017-04-03', '2017-04-04',
#        '2017-04-05', '2017-04-06', '2017-04-07', '2017-04-10',
#        '2017-04-11', '2017-04-12', '2017-04-13', '2017-04-17',
#        '2017-04-18', '2017-04-19', '2017-04-20', '2017-04-21',
#        '2017-04-24', '2017-04-25', '2017-04-26', '2017-04-27',
#        '2017-04-28', '2017-05-01', '2017-05-02', '2017-05-03',
#        '2017-05-04', '2017-05-05', '2017-05-08', '2017-05-09',
#        '2017-05-10', '2017-05-11', '2017-05-12', '2017-05-15',
#        '2017-05-16', '2017-05-17', '2017-05-18', '2017-05-19',
#        '2017-05-22', '2017-05-23', '2017-05-24', '2017-05-25',
#        '2017-05-26', '2017-05-30', '2017-05-31', '2017-06-01',
#        '2017-06-02', '2017-06-05', '2017-06-06', '2017-06-07',
#        '2017-06-08', '2017-06-09', '2017-06-12', '2017-06-13',
#        '2017-06-14', '2017-06-15', '2017-06-16', '2017-06-19',
#        '2017-06-20', '2017-06-21', '2017-06-22', '2017-06-23',
#        '2017-06-26', '2017-06-27', '2017-06-28', '2017-06-29',
#        '2017-06-30', '2017-07-03', '2017-07-05', '2017-07-06',
#        '2017-07-07', '2017-07-10', '2017-07-11', '2017-07-12',
#        '2017-07-13', '2017-07-14', '2017-07-17', '2017-07-18',
#        '2017-07-19', '2017-07-20', '2017-07-21', '2017-07-24',
#        '2017-07-25', '2017-07-26', '2017-07-27', '2017-07-28',
#        '2017-07-31', '2017-08-01', '2017-08-02', '2017-08-03',
#        '2017-08-04', '2017-08-07', '2017-08-08', '2017-08-09',
#        '2017-08-10', '2017-08-11', '2017-08-14', '2017-08-15',
#        '2017-08-16', '2017-08-17', '2017-08-18', '2017-08-21',
#        '2017-08-22', '2017-08-23', '2017-08-24', '2017-08-25',
#        '2017-08-28', '2017-08-29', '2017-08-30', '2017-08-31',
#        '2017-09-01', '2017-09-05', '2017-09-06', '2017-09-07',
#        '2017-09-08', '2017-09-11', '2017-09-12', '2017-09-13',
#        '2017-09-14', '2017-09-15', '2017-09-18', '2017-09-19',
#        '2017-09-20', '2017-09-21', '2017-09-22', '2017-09-25',
#        '2017-09-26', '2017-09-27', '2017-09-28', '2017-09-29',
#        '2017-10-02', '2017-10-03', '2017-10-04', '2017-10-05',
#        '2017-10-06', '2017-10-09', '2017-10-10', '2017-10-11',
#        '2017-10-12', '2017-10-13', '2017-10-16', '2017-10-17',
#        '2017-10-18', '2017-10-19', '2017-10-20', '2017-10-23',
#        '2017-10-24', '2017-10-25', '2017-10-26', '2017-10-27',
#        '2017-10-30', '2017-10-31', '2017-11-01', '2017-11-02',
#        '2017-11-03', '2017-11-06', '2017-11-07', '2017-11-08',
#        '2017-11-09', '2017-11-10', '2017-11-13', '2017-11-14',
#        '2017-11-15', '2017-11-16', '2017-11-17', '2017-11-20',
#        '2017-11-21', '2017-11-22', '2017-11-24', '2017-11-27',
#        '2017-11-28', '2017-11-29', '2017-11-30', '2017-12-01',
#        '2017-12-04', '2017-12-05', '2017-12-06', '2017-12-07',
#        '2017-12-08', '2017-12-11', '2017-12-12', '2017-12-13',
#        '2017-12-14', '2017-12-15', '2017-12-18', '2017-12-19',
#        '2017-12-20', '2017-12-21', '2017-12-22', '2017-12-26',
#        '2017-12-27', '2017-12-28', '2017-12-29'], dtype=object)

# %%
#create a list consisting of the desired dates(March and April)
data_dates = ['2016-03-01',
       '2016-03-02', '2016-03-03', '2016-03-04', '2016-03-07',
       '2016-03-08', '2016-03-09', '2016-03-10', '2016-03-11',
       '2016-03-14', '2016-03-15', '2016-03-16', '2016-03-17',
       '2016-03-18', '2016-03-21', '2016-03-22', '2016-03-23',
       '2016-03-24', '2016-03-28', '2016-03-29', '2016-03-30',
       '2016-03-31', '2016-04-01', '2016-04-04', '2016-04-05',
       '2016-04-06', '2016-04-07', '2016-04-08', '2016-04-11',
       '2016-04-12', '2016-04-13', '2016-04-14', '2016-04-15',
       '2016-04-18', '2016-04-19', '2016-04-20', '2016-04-21',
       '2016-04-22', '2016-04-25', '2016-04-26', '2016-04-27',
       '2016-04-28', '2016-04-29',]

# %%
data = data[['date','mom_05']]  #dropping all other columns to retain portfolio 5 
data
# Out:
#            date  mom_05
# 0    2016-01-04   -1.47
# 1    2016-01-05    0.16
# 2    2016-01-06   -1.70
# 3    2016-01-07   -2.31
# 4    2016-01-08   -1.13
# ..          ...     ...
# 498  2017-12-22   -0.08
# 499  2017-12-26    0.10
# 500  2017-12-27   -0.14
# 501  2017-12-28    0.29
# 502  2017-12-29   -0.45
#
# [503 rows x 2 columns]

# %%
data_newdf = data[data.date.isin(data_dates)]  #new dataframe with only mom_05 values for the months of April and March

data_newdf
# Out:
#           date  mom_05
# 39  2016-03-01    2.61
# 40  2016-03-02    0.58
# 41  2016-03-03    0.71
# 42  2016-03-04    0.73
# 43  2016-03-07    0.63
# 44  2016-03-08   -1.97
# 45  2016-03-09    0.34
# 46  2016-03-10    0.00
# 47  2016-03-11    2.08
# 48  2016-03-14   -0.09
# 49  2016-03-15   -0.04
# 50  2016-03-16    0.61
# 51  2016-03-17    0.68
# 52  2016-03-18    0.87
# 53  2016-03-21    0.20
# 54  2016-03-22   -0.11
# 55  2016-03-23   -1.11
# 56  2016-03-24   -0.21
# 57  2016-03-28   -0.05
# 58  2016-03-29    0.98
# 59  2016-03-30    0.69
# 60  2016-03-31   -0.17
# 61  2016-04-01    0.39
# 62  2016-04-04   -0.08
# 63  2016-04-05   -1.09
# 64  2016-04-06    1.49
# 65  2016-04-07   -1.51
# 66  2016-04-08    0.10
# 67  2016-04-11    0.00
# 68  2016-04-12    1.37
# 69  2016-04-13    1.64
# 70  2016-04-14   -0.08
# 71  2016-04-15   -0.70
# 72  2016-04-18    0.10
# 73  2016-04-19    0.25
# 74  2016-04-20    0.73
# 75  2016-04-21   -0.37
# 76  2016-04-22    0.51
# 77  2016-04-25   -0.29
# 78  2016-04-26    0.35
# 79  2016-04-27   -1.04
# 80  2016-04-28   -1.33
# 81  2016-04-29   -1.43

# %%
#(b)
crimes = pd.read_csv('chicago_past_year_crimes.csv') #loading the crimes csv file 
crimes
# Out:
#            CASE#     DATE  OF OCCURRENCE                   BLOCK  IUCR  \
# 0       JB241987  04/28/2018 10:05:00 PM        009XX N LONG AVE  2092
# 1       JA430240  09/06/2017 01:30:00 PM         032XX W 26TH ST  0810
# 2       JB241350  04/28/2018 08:00:00 AM         008XX E 53RD ST  1320
# 3       JB245397  04/28/2018 09:00:00 AM    062XX S MICHIGAN AVE  0820
# 4       JB241444  04/28/2018 12:15:00 PM      046XX N ELSTON AVE  0890
# ...          ...                     ...                     ...   ...
# 261959  JA385552  08/10/2017 10:30:00 AM         048XX W IOWA ST  1310
# 261960  JA492228  10/30/2017 04:00:00 PM  072XX S SOUTH SHORE DR  0810
# 261961  JA390514  08/13/2017 08:00:00 PM    039XX W VAN BUREN ST  0910
# 261962  JA385930  08/10/2017 04:00:00 AM     071XX S WOLCOTT AVE  1305
# 261963  JA536019  12/02/2017 08:00:00 PM     083XX S INDIANA AVE  1320
#
#         PRIMARY DESCRIPTION           SECONDARY DESCRIPTION  \
# 0                 NARCOTICS  SOLICIT NARCOTICS ON PUBLICWAY
# 1                     THEFT                       OVER $500
# 2           CRIMINAL DAMAGE                      TO VEHICLE
# 3                     THEFT                  $500 AND UNDER
# 4                     THEFT                   FROM BUILDING
# ...                     ...                             ...
# 261959      CRIMINAL DAMAGE                     TO PROPERTY
# 261960                THEFT                       OVER $500
# 261961  MOTOR VEHICLE THEFT                      AUTOMOBILE
# 261962      CRIMINAL DAMAGE             CRIMINAL DEFACEMENT
# 261963      CRIMINAL DAMAGE                      TO VEHICLE
#
#            LOCATION DESCRIPTION ARREST DOMESTIC  BEAT  WARD FBI CD  \
# 0                      SIDEWALK      Y        N  1524  37.0     18
# 1                         OTHER      Y        N  1024  12.0     06
# 2                        STREET      N        N   233   5.0     14
# 3       RESIDENCE PORCH/HALLWAY      N        N   311  20.0     06
# 4            SMALL RETAIL STORE      N        N  1722  39.0     06
# ...                         ...    ...      ...   ...   ...    ...
# 261959                RESIDENCE      N        N  1531  37.0     14
# 261960                APARTMENT      N        Y   334   7.0     06
# 261961                   STREET      N        N  1132  24.0     07
# 261962                RESIDENCE      N        N   735  17.0     14
# 261963                   STREET      N        N   632   6.0     14
#
#         X COORDINATE  Y COORDINATE   LATITUDE  LONGITUDE  \
# 0          1140136.0     1905903.0  41.897895 -87.760744
# 1          1155313.0     1886555.0  41.844510 -87.705519
# 2          1182892.0     1870055.0  41.798635 -87.604823
# 3          1178263.0     1863570.0  41.780946 -87.621995
# 4          1146646.0     1930549.0  41.965404 -87.736202
# ...              ...           ...        ...        ...
# 261959     1143912.0     1905538.0  41.896823 -87.746884
# 261960     1194878.0     1857803.0  41.764728 -87.561272
# 261961     1150218.0     1897735.0  41.875290 -87.723926
# 261962     1164921.0     1857378.0  41.764247 -87.671085
# 261963     1179046.0     1849699.0  41.742865 -87.619547
#
#                              LOCATION
# 0       (41.897894893, -87.760743714)
# 1       (41.844510467, -87.705519454)
# 2       (41.798635468, -87.604823241)
# 3       (41.780946398, -87.621995369)
# 4       (41.965404069, -87.736202402)
# ...                               ...
# 261959     (41.8968233, -87.74688383)
# 261960  (41.764728045, -87.561272312)
# 261961  (41.875290412, -87.723926225)
# 261962  (41.764247182, -87.671084615)
# 261963  (41.742865052, -87.619546732)
#
# [261964 rows x 17 columns]

# %%
crimes.columns  #print out the dataframe column names
# Out:
# Index(['CASE#', 'DATE  OF OCCURRENCE', 'BLOCK', ' IUCR',
#        ' PRIMARY DESCRIPTION', ' SECONDARY DESCRIPTION',
#        ' LOCATION DESCRIPTION', 'ARREST', 'DOMESTIC', 'BEAT', 'WARD', 'FBI CD',
#        'X COORDINATE', 'Y COORDINATE', 'LATITUDE', 'LONGITUDE', 'LOCATION'],
#       dtype='object')

# %%
#1.
crimes.columns = crimes.columns.str.lstrip()  #removes white space at the start of a string

# %%
#2.
crimes.columns = crimes.columns.str.replace(' ', '_') #replacing the rest of the white spaces with underscores

# %%
#4.
crimes.drop(['LOCATION'], axis=1, inplace=True)  #drop the Location column, axis=1 specifies that it's a column
crimes
# Out:
#            CASE#     DATE__OF_OCCURRENCE                   BLOCK  IUCR  \
# 0       JB241987  04/28/2018 10:05:00 PM        009XX N LONG AVE  2092
# 1       JA430240  09/06/2017 01:30:00 PM         032XX W 26TH ST  0810
# 2       JB241350  04/28/2018 08:00:00 AM         008XX E 53RD ST  1320
# 3       JB245397  04/28/2018 09:00:00 AM    062XX S MICHIGAN AVE  0820
# 4       JB241444  04/28/2018 12:15:00 PM      046XX N ELSTON AVE  0890
# ...          ...                     ...                     ...   ...
# 261959  JA385552  08/10/2017 10:30:00 AM         048XX W IOWA ST  1310
# 261960  JA492228  10/30/2017 04:00:00 PM  072XX S SOUTH SHORE DR  0810
# 261961  JA390514  08/13/2017 08:00:00 PM    039XX W VAN BUREN ST  0910
# 261962  JA385930  08/10/2017 04:00:00 AM     071XX S WOLCOTT AVE  1305
# 261963  JA536019  12/02/2017 08:00:00 PM     083XX S INDIANA AVE  1320
#
#         PRIMARY_DESCRIPTION           SECONDARY_DESCRIPTION  \
# 0                 NARCOTICS  SOLICIT NARCOTICS ON PUBLICWAY
# 1                     THEFT                       OVER $500
# 2           CRIMINAL DAMAGE                      TO VEHICLE
# 3                     THEFT                  $500 AND UNDER
# 4                     THEFT                   FROM BUILDING
# ...                     ...                             ...
# 261959      CRIMINAL DAMAGE                     TO PROPERTY
# 261960                THEFT                       OVER $500
# 261961  MOTOR VEHICLE THEFT                      AUTOMOBILE
# 261962      CRIMINAL DAMAGE             CRIMINAL DEFACEMENT
# 261963      CRIMINAL DAMAGE                      TO VEHICLE
#
#            LOCATION_DESCRIPTION ARREST DOMESTIC  BEAT  WARD FBI_CD  \
# 0                      SIDEWALK      Y        N  1524  37.0     18
# 1                         OTHER      Y        N  1024  12.0     06
# 2                        STREET      N        N   233   5.0     14
# 3       RESIDENCE PORCH/HALLWAY      N        N   311  20.0     06
# 4            SMALL RETAIL STORE      N        N  1722  39.0     06
# ...                         ...    ...      ...   ...   ...    ...
# 261959                RESIDENCE      N        N  1531  37.0     14
# 261960                APARTMENT      N        Y   334   7.0     06
# 261961                   STREET      N        N  1132  24.0     07
# 261962                RESIDENCE      N        N   735  17.0     14
# 261963                   STREET      N        N   632   6.0     14
#
#         X_COORDINATE  Y_COORDINATE   LATITUDE  LONGITUDE
# 0          1140136.0     1905903.0  41.897895 -87.760744
# 1          1155313.0     1886555.0  41.844510 -87.705519
# 2          1182892.0     1870055.0  41.798635 -87.604823
# 3          1178263.0     1863570.0  41.780946 -87.621995
# 4          1146646.0     1930549.0  41.965404 -87.736202
# ...              ...           ...        ...        ...
# 261959     1143912.0     1905538.0  41.896823 -87.746884
# 261960     1194878.0     1857803.0  41.764728 -87.561272
# 261961     1150218.0     1897735.0  41.875290 -87.723926
# 261962     1164921.0     1857378.0  41.764247 -87.671085
# 261963     1179046.0     1849699.0  41.742865 -87.619547
#
# [261964 rows x 16 columns]

# %%
#5.
crimes.isnull().count() #generating a sum (of null).
# Out:
# CASE#                    261964
# DATE__OF_OCCURRENCE      261964
# BLOCK                    261964
# IUCR                     261964
# PRIMARY_DESCRIPTION      261964
# SECONDARY_DESCRIPTION    261964
# LOCATION_DESCRIPTION     261964
# ARREST                   261964
# DOMESTIC                 261964
# BEAT                     261964
# WARD                     261964
# FBI_CD                   261964
# X_COORDINATE             261964
# Y_COORDINATE             261964
# LATITUDE                 261964
# LONGITUDE                261964
# dtype: int64

# %%
#6.QUOTE METHOD,to display the data in the primary_description column 
crimes['PRIMARY_DESCRIPTION']
# Out:
# 0                   NARCOTICS
# 1                       THEFT
# 2             CRIMINAL DAMAGE
# 3                       THEFT
# 4                       THEFT
#                  ...
# 261959        CRIMINAL DAMAGE
# 261960                  THEFT
# 261961    MOTOR VEHICLE THEFT
# 261962        CRIMINAL DAMAGE
# 261963        CRIMINAL DAMAGE
# Name: PRIMARY_DESCRIPTION, Length: 261964, dtype: object

# %%
#7 value counts to check the number of occurences for each crime
crimes['PRIMARY_DESCRIPTION'].value_counts()
# Out:
# THEFT                                63821
# BATTERY                              48917
# CRIMINAL DAMAGE                      28085
# ASSAULT                              19580
# DECEPTIVE PRACTICE                   17672
# OTHER OFFENSE                        16407
# BURGLARY                             12104
# NARCOTICS                            11448
# ROBBERY                              11292
# MOTOR VEHICLE THEFT                  10815
# CRIMINAL TRESPASS                     6881
# WEAPONS VIOLATION                     4867
# OFFENSE INVOLVING CHILDREN            2222
# CRIM SEXUAL ASSAULT                   1515
# PUBLIC PEACE VIOLATION                1427
# INTERFERENCE WITH PUBLIC OFFICER      1151
# SEX OFFENSE                            970
# PROSTITUTION                           649
# HOMICIDE                               627
# ARSON                                  382
# LIQUOR LAW VIOLATION                   207
# KIDNAPPING                             191
# GAMBLING                               180
# STALKING                               168
# INTIMIDATION                           138
# OBSCENITY                               91
# CONCEALED CARRY LICENSE VIOLATION       83
# NON-CRIMINAL                            45
# OTHER NARCOTIC VIOLATION                10
# PUBLIC INDECENCY                        10
# HUMAN TRAFFICKING                        8
# NON-CRIMINAL (SUBJECT SPECIFIED)         1
# Name: PRIMARY_DESCRIPTION, dtype: int64

# %%
#8. display the first 10 columns of two chosen columns
crimes[['PRIMARY_DESCRIPTION', 'SECONDARY_DESCRIPTION']].head(10)
# Out:
#    PRIMARY_DESCRIPTION           SECONDARY_DESCRIPTION
# 0            NARCOTICS  SOLICIT NARCOTICS ON PUBLICWAY
# 1                THEFT                       OVER $500
# 2      CRIMINAL DAMAGE                      TO VEHICLE
# 3                THEFT                  $500 AND UNDER
# 4                THEFT                   FROM BUILDING
# 5                ARSON                         BY FIRE
# 6  MOTOR VEHICLE THEFT                      AUTOMOBILE
# 7              ROBBERY  AGGRAVATED VEHICULAR HIJACKING
# 8              BATTERY                          SIMPLE
# 9              ROBBERY  ARMED:KNIFE/CUTTING INSTRUMENT

# %%
#subset by row index
crimes[['PRIMARY_DESCRIPTION', 'SECONDARY_DESCRIPTION']].iloc[3:10]
# Out:
#    PRIMARY_DESCRIPTION           SECONDARY_DESCRIPTION
# 3                THEFT                  $500 AND UNDER
# 4                THEFT                   FROM BUILDING
# 5                ARSON                         BY FIRE
# 6  MOTOR VEHICLE THEFT                      AUTOMOBILE
# 7              ROBBERY  AGGRAVATED VEHICULAR HIJACKING
# 8              BATTERY                          SIMPLE
# 9              ROBBERY  ARMED:KNIFE/CUTTING INSTRUMENT

# %%
#9 
crimes.sort_values(by=['PRIMARY_DESCRIPTION'], inplace=True) #sort values by Primary_description column, in ascending order
crimes
# Out:
#            CASE#     DATE__OF_OCCURRENCE                      BLOCK  IUCR  \
# 233057  JA411498  08/30/2017 12:45:00 AM            014XX W 90TH ST  1020
# 245301  JA310992  06/17/2017 01:17:00 PM      003XX W GARFIELD BLVD  1020
# 56001   JB232542  04/21/2018 10:00:00 AM            007XX W 72ND ST  1020
# 46865   JA290174  06/02/2017 09:59:00 PM        037XX W GIDDINGS ST  1020
# 106692  JA380184  08/06/2017 06:50:00 PM           001XX W 107TH ST  1090
# ...          ...                     ...                        ...   ...
# 158387  JA467903  10/11/2017 10:06:00 PM  088XX S COTTAGE GROVE AVE  143A
# 257631  JA290099  06/02/2017 08:16:00 PM       069XX S EAST END AVE  143A
# 173801  JA484892  10/25/2017 01:59:00 AM   077XX S DAN RYAN EXPY OB  143A
# 245269  JA353259  07/18/2017 02:38:00 PM        007XX N LATROBE AVE  143A
# 118044  JA388729  08/12/2017 08:50:00 PM            007XX E 90TH PL  143A
#
#        PRIMARY_DESCRIPTION     SECONDARY_DESCRIPTION    LOCATION_DESCRIPTION  \
# 233057               ARSON                   BY FIRE  VEHICLE NON-COMMERCIAL
# 245301               ARSON                   BY FIRE      ABANDONED BUILDING
# 56001                ARSON                   BY FIRE               APARTMENT
# 46865                ARSON                   BY FIRE        RESIDENCE-GARAGE
# 106692               ARSON             ATTEMPT ARSON               RESIDENCE
# ...                    ...                       ...                     ...
# 158387   WEAPONS VIOLATION  UNLAWFUL POSS OF HANDGUN                   ALLEY
# 257631   WEAPONS VIOLATION  UNLAWFUL POSS OF HANDGUN                  STREET
# 173801   WEAPONS VIOLATION  UNLAWFUL POSS OF HANDGUN      HIGHWAY/EXPRESSWAY
# 245269   WEAPONS VIOLATION  UNLAWFUL POSS OF HANDGUN               RESIDENCE
# 118044   WEAPONS VIOLATION  UNLAWFUL POSS OF HANDGUN                  STREET
#
#        ARREST DOMESTIC  BEAT  WARD FBI_CD  X_COORDINATE  Y_COORDINATE  \
# 233057      N        N  2222  21.0     09     1168404.0     1845068.0
# 245301      N        N   711   3.0     09     1175061.0     1868356.0
# 56001       N        N   732   6.0     09     1172786.0     1857137.0
# 46865       N        N  1723  39.0     09     1150539.0     1931303.0
# 106692      N        Y   513  34.0     09     1177389.0     1834006.0
# ...       ...      ...   ...   ...    ...           ...           ...
# 158387      Y        N   632   8.0     15     1183114.0     1846334.0
# 257631      Y        N   332   5.0     15     1188976.0     1859328.0
# 173801      Y        N   623   6.0     15     1177343.0     1853906.0
# 245269      N        N  1524  28.0     15     1141223.0     1904450.0
# 118044      Y        N   633   6.0     15     1182717.0     1845130.0
#
#          LATITUDE  LONGITUDE
# 233057  41.730393 -87.658672
# 245301  41.794152 -87.633592
# 56001   41.763416 -87.642265
# 46865   41.967398 -87.721869
# 106692  41.699839 -87.626090
# ...           ...        ...
# 158387  41.733538 -87.604746
# 257631  41.769056 -87.582856
# 173801  41.754448 -87.625660
# 245269  41.893888 -87.756787
# 118044  41.730243 -87.606238
#
# [261964 rows x 16 columns]

# %%
#
crimes.groupby([''])[]

# %% [markdown]
# ## Question 2
#
# (a). What is the standard deviation of the data:
#
# $$ 1, 3, 1, 2,9, 4, 5, 6, 10, 4 $$
#
# **Note** Use 1 degree of freedom in the denominator.
#
#
# (b). Importing all relevant libraries
#
# `import pandas as pd, import numpy as np
# import matplotlib.pyplot as plt
# plt.style.use('ggplot')
# import math
# import requests
# from bs4 import BeautifulSoup
# from selenium import webdriver
# import datetime
# import dateutil.parser
# import time
# import re
# import statsmodels.api as sm
# import statsmodels.formula.api as smf
# import sklearn
# from tqdm import tqdm_notebook
# pd.options.mode.chained_assignment = None`.
#
# Following the same format of code below:
#
# `team_converter = pd.read_csv("source_files/team_converter.csv",encoding="cp1252")
# big_five_league_fixtures = pd.read_csv("source_files/big_five_league_fixtures.csv")
# big_five_league_fixtures["date"] = big_five_league_fixtures["date"].apply(lambda x:datetime.datetime.strptime(x,"%d/%m/%Y").date())
# big_five_league_fixtures["home_points"] = big_five_league_fixtures["result"].map({"H":3,"D":1,"A":0})
# big_five_league_fixtures["away_points"] = big_five_league_fixtures["result"].map({"A":3,"D":1,"H":0})`
#
# `FIFA_league_season_teams_df = pd.read_csv("output_files/FIFA_league_season_teams_df.csv")
# FIFA_team_season_players_df = pd.read_csv("output_files/FIFA_team_season_players_df.csv")
# TM_team_managers_df = pd.read_csv("output_files/TM_team_managers_df.csv")`
#
# import and load all files as specified in the code
#
# b).
#
# (i). Run the code and adjust appropriate file paths to import and convert the dataset into proper format.
#
# (ii). Join the team ids onto fixture data. HINT: Using the same conversion and format of this exmple : First line of code `FIFA_edition_dict = {
#     "FIFA 2005":["08/10/2004","/fifa05_1/"],.....}` to complete all the joins for all years.
#
# (iii). Join Manager tenure onto fixture data.
#
# (iv). Join expected points onto fixture data.
#
# (v). Create dataframe of each team's performance in each season
#
# (vi). Create dataframe of each manager tenure, with past and future performance

# %% [markdown]
# ## Question 3
#
# (a). Load the covid-19 dataset in the CSV file `COVID-19 Cases.csv`, set the column `date` as the index, and ensure that `date` is a `DateTimeIndex`. Print a view of first 10 lines of the dataset. Next we will isolate the data we want to focus our attention on by creating a new DataFrame from the source, and by applying a few filters against it. We want to isolate the records where all the following conditions are true. First the Daily Difference count is greater than zero. Next the Case Type should be Confirmed. Finally, the Country_Region should be only Italy: Check whether the results are sorted by cases & ascending order to  well and accordingly, write the command to accomplish it:
#
# (b). Now lets visually display the distribution of the values in the Difference column. We can pass an array of values into the default hist() plot (`plot the histogram using the Difference Column`):
#
# (c). Obtain descriptive and inferential statics on at least three columns & create a new DataFrame out of the three columns computed statistics on.
#
# (d). Obtain a boxplot of the selected number of columns of your choice in the dataset. Interprete the resulting chart (boxplot) to make meaning out of it.

# %%
#3(a)
Data = pd.read_csv('COVID-19 Cases.csv') #load the Covid-19 cases csv
#pd.to_datetime(Data.Date)  #set the Date to a DateTimeIndex
Data
# Out:
#             Date Country_Region Province_State  Difference  \
# 0       3/9/2020          India            NaN           0
# 1       3/8/2020          India            NaN           0
# 2       3/7/2020          India            NaN           0
# 3       3/6/2020          India            NaN           0
# 4       3/5/2020          India            NaN           0
# ...          ...            ...            ...         ...
# 35497  1/27/2020          Syria            NaN           0
# 35498  1/26/2020          Syria            NaN           0
# 35499  1/25/2020          Syria            NaN           0
# 35500  1/24/2020          Syria            NaN           0
# 35501  1/23/2020          Syria            NaN           0
#
#           Prep_Flow_Runtime Latest_Date  Case_Type  Cases        Lat  \
# 0      3/24/2020 9:39:03 AM   3/23/2020     Deaths      0  21.000000
# 1      3/24/2020 9:39:03 AM   3/23/2020     Deaths      0  21.000000
# 2      3/24/2020 9:39:03 AM   3/23/2020     Deaths      0  21.000000
# 3      3/24/2020 9:39:03 AM   3/23/2020     Deaths      0  21.000000
# 4      3/24/2020 9:39:03 AM   3/23/2020     Deaths      0  21.000000
# ...                     ...         ...        ...    ...        ...
# 35497  3/24/2020 9:39:03 AM   3/23/2020  Confirmed      0  34.802075
# 35498  3/24/2020 9:39:03 AM   3/23/2020  Confirmed      0  34.802075
# 35499  3/24/2020 9:39:03 AM   3/23/2020  Confirmed      0  34.802075
# 35500  3/24/2020 9:39:03 AM   3/23/2020  Confirmed      0  34.802075
# 35501  3/24/2020 9:39:03 AM   3/23/2020  Confirmed      0  34.802075
#
#             Long
# 0      78.000000
# 1      78.000000
# 2      78.000000
# 3      78.000000
# 4      78.000000
# ...          ...
# 35497  38.996815
# 35498  38.996815
# 35499  38.996815
# 35500  38.996815
# 35501  38.996815
#
# [35502 rows x 10 columns]

# %%
Data.set_index('Date', inplace = True)   #set date as index
Data
# Out:
#           Country_Region Province_State  Difference     Prep_Flow_Runtime  \
# Date
# 3/9/2020           India            NaN           0  3/24/2020 9:39:03 AM
# 3/8/2020           India            NaN           0  3/24/2020 9:39:03 AM
# 3/7/2020           India            NaN           0  3/24/2020 9:39:03 AM
# 3/6/2020           India            NaN           0  3/24/2020 9:39:03 AM
# 3/5/2020           India            NaN           0  3/24/2020 9:39:03 AM
# ...                  ...            ...         ...                   ...
# 1/27/2020          Syria            NaN           0  3/24/2020 9:39:03 AM
# 1/26/2020          Syria            NaN           0  3/24/2020 9:39:03 AM
# 1/25/2020          Syria            NaN           0  3/24/2020 9:39:03 AM
# 1/24/2020          Syria            NaN           0  3/24/2020 9:39:03 AM
# 1/23/2020          Syria            NaN           0  3/24/2020 9:39:03 AM
#
#           Latest_Date  Case_Type  Cases        Lat       Long
# Date
# 3/9/2020    3/23/2020     Deaths      0  21.000000  78.000000
# 3/8/2020    3/23/2020     Deaths      0  21.000000  78.000000
# 3/7/2020    3/23/2020     Deaths      0  21.000000  78.000000
# 3/6/2020    3/23/2020     Deaths      0  21.000000  78.000000
# 3/5/2020    3/23/2020     Deaths      0  21.000000  78.000000
# ...               ...        ...    ...        ...        ...
# 1/27/2020   3/23/2020  Confirmed      0  34.802075  38.996815
# 1/26/2020   3/23/2020  Confirmed      0  34.802075  38.996815
# 1/25/2020   3/23/2020  Confirmed      0  34.802075  38.996815
# 1/24/2020   3/23/2020  Confirmed      0  34.802075  38.996815
# 1/23/2020   3/23/2020  Confirmed      0  34.802075  38.996815
#
# [35502 rows x 9 columns]

# %%
Data.head(10)  #prints the first 10 lines of the dataset
# Out:
#           Country_Region Province_State  Difference     Prep_Flow_Runtime  \
# Date
# 3/9/2020           India            NaN           0  3/24/2020 9:39:03 AM
# 3/8/2020           India            NaN           0  3/24/2020 9:39:03 AM
# 3/7/2020           India            NaN           0  3/24/2020 9:39:03 AM
# 3/6/2020           India            NaN           0  3/24/2020 9:39:03 AM
# 3/5/2020           India            NaN           0  3/24/2020 9:39:03 AM
# 3/4/2020           India            NaN           0  3/24/2020 9:39:03 AM
# 3/3/2020           India            NaN           0  3/24/2020 9:39:03 AM
# 3/23/2020          India            NaN           3  3/24/2020 9:39:03 AM
# 3/22/2020          India            NaN           3  3/24/2020 9:39:03 AM
# 3/21/2020          India            NaN          -1  3/24/2020 9:39:03 AM
#
#           Latest_Date Case_Type  Cases   Lat  Long
# Date
# 3/9/2020    3/23/2020    Deaths      0  21.0  78.0
# 3/8/2020    3/23/2020    Deaths      0  21.0  78.0
# 3/7/2020    3/23/2020    Deaths      0  21.0  78.0
# 3/6/2020    3/23/2020    Deaths      0  21.0  78.0
# 3/5/2020    3/23/2020    Deaths      0  21.0  78.0
# 3/4/2020    3/23/2020    Deaths      0  21.0  78.0
# 3/3/2020    3/23/2020    Deaths      0  21.0  78.0
# 3/23/2020   3/23/2020    Deaths     10  21.0  78.0
# 3/22/2020   3/23/2020    Deaths      7  21.0  78.0
# 3/21/2020   3/23/2020    Deaths      4  21.0  78.0

# %%
#new dataset, isolate

Data_1 = Data[(Data.Case_Type =='Confirmed') & (Data.Country_Region == 'Italy') & (Data.Difference >0)] #confirmed cases, country region, Italy,difference is greater than zero

Data_1.sort_values(by=['Cases'],ascending=True) #sort the dataframe by Cases column in ascending order

Data_1
# Out:
#           Country_Region Province_State  Difference     Prep_Flow_Runtime  \
# Date
# 3/9/2020           Italy            NaN        1797  3/24/2020 9:39:03 AM
# 3/8/2020           Italy            NaN        1492  3/24/2020 9:39:03 AM
# 3/7/2020           Italy            NaN        1247  3/24/2020 9:39:03 AM
# 3/6/2020           Italy            NaN         778  3/24/2020 9:39:03 AM
# 3/5/2020           Italy            NaN         769  3/24/2020 9:39:03 AM
# 3/4/2020           Italy            NaN         587  3/24/2020 9:39:03 AM
# 3/3/2020           Italy            NaN         466  3/24/2020 9:39:03 AM
# 3/23/2020          Italy            NaN        4789  3/24/2020 9:39:03 AM
# 3/22/2020          Italy            NaN        5560  3/24/2020 9:39:03 AM
# 3/21/2020          Italy            NaN        6557  3/24/2020 9:39:03 AM
# 3/20/2020          Italy            NaN        5986  3/24/2020 9:39:03 AM
# 3/2/2020           Italy            NaN         342  3/24/2020 9:39:03 AM
# 3/19/2020          Italy            NaN        5322  3/24/2020 9:39:03 AM
# 3/18/2020          Italy            NaN        4207  3/24/2020 9:39:03 AM
# 3/17/2020          Italy            NaN        3526  3/24/2020 9:39:03 AM
# 3/16/2020          Italy            NaN        3233  3/24/2020 9:39:03 AM
# 3/15/2020          Italy            NaN        3590  3/24/2020 9:39:03 AM
# 3/14/2020          Italy            NaN        3497  3/24/2020 9:39:03 AM
# 3/13/2020          Italy            NaN        5198  3/24/2020 9:39:03 AM
# 3/11/2020          Italy            NaN        2313  3/24/2020 9:39:03 AM
# 3/10/2020          Italy            NaN         977  3/24/2020 9:39:03 AM
# 3/1/2020           Italy            NaN         566  3/24/2020 9:39:03 AM
# 2/7/2020           Italy            NaN           1  3/24/2020 9:39:03 AM
# 2/29/2020          Italy            NaN         240  3/24/2020 9:39:03 AM
# 2/28/2020          Italy            NaN         233  3/24/2020 9:39:03 AM
# 2/27/2020          Italy            NaN         202  3/24/2020 9:39:03 AM
# 2/26/2020          Italy            NaN         131  3/24/2020 9:39:03 AM
# 2/25/2020          Italy            NaN          93  3/24/2020 9:39:03 AM
# 2/24/2020          Italy            NaN          74  3/24/2020 9:39:03 AM
# 2/23/2020          Italy            NaN          93  3/24/2020 9:39:03 AM
# 2/22/2020          Italy            NaN          42  3/24/2020 9:39:03 AM
# 2/21/2020          Italy            NaN          17  3/24/2020 9:39:03 AM
# 1/31/2020          Italy            NaN           2  3/24/2020 9:39:03 AM
#
#           Latest_Date  Case_Type  Cases   Lat  Long
# Date
# 3/9/2020    3/23/2020  Confirmed   9172  43.0  12.0
# 3/8/2020    3/23/2020  Confirmed   7375  43.0  12.0
# 3/7/2020    3/23/2020  Confirmed   5883  43.0  12.0
# 3/6/2020    3/23/2020  Confirmed   4636  43.0  12.0
# 3/5/2020    3/23/2020  Confirmed   3858  43.0  12.0
# 3/4/2020    3/23/2020  Confirmed   3089  43.0  12.0
# 3/3/2020    3/23/2020  Confirmed   2502  43.0  12.0
# 3/23/2020   3/23/2020  Confirmed  63927  43.0  12.0
# 3/22/2020   3/23/2020  Confirmed  59138  43.0  12.0
# 3/21/2020   3/23/2020  Confirmed  53578  43.0  12.0
# 3/20/2020   3/23/2020  Confirmed  47021  43.0  12.0
# 3/2/2020    3/23/2020  Confirmed   2036  43.0  12.0
# 3/19/2020   3/23/2020  Confirmed  41035  43.0  12.0
# 3/18/2020   3/23/2020  Confirmed  35713  43.0  12.0
# 3/17/2020   3/23/2020  Confirmed  31506  43.0  12.0
# 3/16/2020   3/23/2020  Confirmed  27980  43.0  12.0
# 3/15/2020   3/23/2020  Confirmed  24747  43.0  12.0
# 3/14/2020   3/23/2020  Confirmed  21157  43.0  12.0
# 3/13/2020   3/23/2020  Confirmed  17660  43.0  12.0
# 3/11/2020   3/23/2020  Confirmed  12462  43.0  12.0
# 3/10/2020   3/23/2020  Confirmed  10149  43.0  12.0
# 3/1/2020    3/23/2020  Confirmed   1694  43.0  12.0
# 2/7/2020    3/23/2020  Confirmed      3  43.0  12.0
# 2/29/2020   3/23/2020  Confirmed   1128  43.0  12.0
# 2/28/2020   3/23/2020  Confirmed    888  43.0  12.0
# 2/27/2020   3/23/2020  Confirmed    655  43.0  12.0
# 2/26/2020   3/23/2020  Confirmed    453  43.0  12.0
# 2/25/2020   3/23/2020  Confirmed    322  43.0  12.0
# 2/24/2020   3/23/2020  Confirmed    229  43.0  12.0
# 2/23/2020   3/23/2020  Confirmed    155  43.0  12.0
# 2/22/2020   3/23/2020  Confirmed     62  43.0  12.0
# 2/21/2020   3/23/2020  Confirmed     20  43.0  12.0
# 1/31/2020   3/23/2020  Confirmed      2  43.0  12.0

# %%
#b. visualise the Difference column, using a histogram
Data_1.hist(column = 'Difference');

# %% [markdown]
# ## Question 4
#
# (a). Write the function `QUESTION_20` that will take a single input `s`, which is a string
# and will return a Series that counts the number of times each letter in `s` appears in `s`
# _without_ regard to case. Do not include spaces.  Ensure the Series returned as its index sorted.
#
# **Hints**:
#
# * Have a look at `value_counts` for a pandas `Series`.
# * You can iterate across the letters of a string using
#
# ```
# some_string = 'abcdefg'
# for letter in some_string:
#     do somethign with letter...
# ```
# * `str.lower` can be used to get the lower case version of a string
#
# (b). Use binary ufuncs, to do some interesting aggregates that can be computed directly from the object.
# For example, if we'd like to *reduce* an array with a particular operation, we can use the ``reduce`` method of any ufunc.
# A reduce repeatedly applies a given operation to the elements of an array until only a single result remains.
#
# For example, calling ``reduce`` on the ``add`` ufunc returns the sum of all elements in the array: `For x = np.arange(1, 6)`
#
# (i). reduce `x`
#
# (ii). add `x`
#
# (iii). multiply `x`
#
# (iv). accumulate `x`
#
# (v). compute additiona and accumulation in one row `x`
#
# (vi). compute multiplication and accumulation in one row `x`
#
# (V). do an outer product of `x`

# %% [markdown]
# GOOD LUCK & `Be Not afraid of going slowly, be afraid of standing still` Old Chineese proverb
